# %% [markdown]
# # Run Experiment Pipeline
# This notebook allows you to easily install dependencies and run Python scripts natively.
#
# ### 1. Install Dependencies
# Run the cell below once to install required packages.

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ### 2. Run Parallel Experiments (Custom Parameters)
# Change the `--fold`, `--seed`, and `--dataset` parameters below to run specific subsets of the experiment.

# %%
# %run experiment.py --dataset Plant_oil --fold 1 --seed 5
# Out:
# ...
# Running experiment for Plant_oil
# ...
#
# --- Fold 1/10 ---
#
#   >> Seed sets per label: 5
#     Evaluating Model: KNN
#       -> [Baseline] Acc: 0.8094, F1: 0.7966, Time: 0.07s
#       [+] Saved to Plant_oil_F1_S5_results.csv
#       HP Tuning KNN...
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
#       -> [Tuned_Baseline] Acc: 0.8081, F1: 0.7937, Time: 0.12s
#       [+] Saved to Plant_oil_F1_S5_results.csv
#       Generating 2x synthetic data with Jittering...
#       -> [Jittering @ 2x] Acc: 0.8058, F1: 0.7916, Time: 0.17s
#       [+] Saved to Plant_oil_F1_S5_results.csv
#       Generating 5x synthetic data with Jittering...
#       -> [Jittering @ 5x] Acc: 0.8066, F1: 0.7925, Time: 0.25s
#       [+] Saved to Plant_oil_F1_S5_results.csv
#       Generating 10x synthetic data with Jittering...
#       -> [Jittering @ 10x] Acc: 0.8067, F1: 0.7929, Time: 0.37s
#       [+] Saved to Plant_oil_F1_S5_results.csv
#       Generating 20x synthetic data with Jittering...
# ...

# %%
# %run experiment.py --dataset Plant_oil --fold 2 --seed 5
# Out:
# ...
# Running experiment for Plant_oil
# ...
#
# --- Fold 2/10 ---
#
#   >> Seed sets per label: 5
#     Evaluating Model: KNN
#       -> [Baseline] Acc: 0.8195, F1: 0.8068, Time: 0.07s
#       [+] Saved to Plant_oil_F2_S5_results.csv
#       HP Tuning KNN...
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
#       -> [Tuned_Baseline] Acc: 0.8040, F1: 0.7915, Time: 0.08s
#       [+] Saved to Plant_oil_F2_S5_results.csv
#       Generating 2x synthetic data with Jittering...
#       -> [Jittering @ 2x] Acc: 0.8021, F1: 0.7893, Time: 0.13s
#       [+] Saved to Plant_oil_F2_S5_results.csv
#       Generating 5x synthetic data with Jittering...
#       -> [Jittering @ 5x] Acc: 0.8037, F1: 0.7907, Time: 0.21s
#       [+] Saved to Plant_oil_F2_S5_results.csv
#       Generating 10x synthetic data with Jittering...
#       -> [Jittering @ 10x] Acc: 0.8040, F1: 0.7910, Time: 0.32s
#       [+] Saved to Plant_oil_F2_S5_results.csv
#       Generating 20x synthetic data with Jittering...
# ...

# %%
# %run experiment.py --dataset Plant_oil --fold 3 --seed 5
# Out:
# ...
# Running experiment for Plant_oil
# ...
#
# --- Fold 3/10 ---
#
#   >> Seed sets per label: 5
#     Evaluating Model: KNN
#       -> [Baseline] Acc: 0.8645, F1: 0.8655, Time: 0.07s
#       [+] Saved to Plant_oil_F3_S5_results.csv
#       HP Tuning KNN...
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# C:\ProgramData\anaconda3\Lib\site-packages\joblib\externals\loky\backend\resource_tracker.py:146: UserWarning: resource_tracker: process died unexpectedly, relaunching. Some folders/semaphores might leak.
#   warnings.warn(

# %%
# %run experiment.py --dataset Plant_oil --fold 4 --seed 5

# %%
# %run experiment.py --dataset Plant_oil --fold 5 --seed 5

# %%
# %run experiment.py --dataset Plant_oil --fold 6 --seed 5

# %%
# %run experiment.py --dataset Plant_oil --fold 7 --seed 5

# %%
# %run experiment.py --dataset Plant_oil --fold 8 --seed 5

# %%
# %run experiment.py --dataset Plant_oil --fold 9 --seed 5

# %%
# %run experiment.py --dataset Plant_oil --fold 10 --seed 5

# %%
# Run all seeds for the Plant_oil dataset, but only on fold 2
# %run experiment.py --dataset Plant_oil --fold 2

# Run the full experiment across all datasets, folds, and seeds (Takes significant time)
# %run experiment.py
