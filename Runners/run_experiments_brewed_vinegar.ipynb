# %% [markdown]
# # Run Experiment Pipeline for Brewed_vinegar
# To ensure safety and track progress, the experiment is split into 3 cells corresponding to Seed Size: 1, 2, 5.
# The results of each cell will be saved to a separate CSV file.

# %%
# %run ../experiment.py --dataset Brewed_vinegar --seed 1
# Out:
# ...
# Running experiment for Brewed_vinegar
# ...
#
# --- Fold 1/10 ---
#
#   >> Seed sets per label: 1
#     Evaluating Model: KNN
#       -> [Baseline] Acc: 0.9733, F1: 0.9733, Time: 0.01s
#       [+] Saved to Brewed_vinegar_S1_results.csv
#       HP Tuning KNN...
# n_iterations: 3
# n_required_iterations: 3
# n_possible_iterations: 3
# min_resources_: 24
# max_resources_: 600
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 20
# n_resources: 24
# Fitting 2 folds for each of 20 candidates, totalling 40 fits
# ----------
# iter: 1
# n_candidates: 7
# n_resources: 72
# Fitting 2 folds for each of 7 candidates, totalling 14 fits
# ----------
# iter: 2
# n_candidates: 3
# n_resources: 216
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
#       -> [Tuned_Baseline] Acc: 0.9673, F1: 0.9673, Time: 0.01s
#       [+] Saved to Brewed_vinegar_S1_results.csv
#       Generating 2x synthetic data with Jittering...
# ...

# %%
# %run ../experiment.py --dataset Brewed_vinegar --seed 2
# Out:
# ...
# Running experiment for Brewed_vinegar
# ...
#
# --- Fold 1/10 ---
#
#   >> Seed sets per label: 2
#     Evaluating Model: KNN
#       -> [Baseline] Acc: 0.9953, F1: 0.9953, Time: 0.01s
#       [+] Saved to Brewed_vinegar_S2_results.csv
#       HP Tuning KNN...
# n_iterations: 3
# n_required_iterations: 3
# n_possible_iterations: 4
# min_resources_: 24
# max_resources_: 1200
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 20
# n_resources: 24
# Fitting 2 folds for each of 20 candidates, totalling 40 fits
# ----------
# iter: 1
# n_candidates: 7
# n_resources: 72
# Fitting 2 folds for each of 7 candidates, totalling 14 fits
# ----------
# iter: 2
# n_candidates: 3
# n_resources: 216
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
#       -> [Tuned_Baseline] Acc: 0.9940, F1: 0.9940, Time: 0.01s
#       [+] Saved to Brewed_vinegar_S2_results.csv
#       Generating 2x synthetic data with Jittering...
# ...

# %%
# %run ../experiment.py --dataset Brewed_vinegar --seed 5
# Out:
# ...
# Running experiment for Brewed_vinegar
# ...
#
# --- Fold 1/10 ---
#
#   >> Seed sets per label: 5
#     Evaluating Model: KNN
#       -> [Baseline] Acc: 1.0000, F1: 1.0000, Time: 0.01s
#       [+] Saved to Brewed_vinegar_S5_results.csv
#       HP Tuning KNN...
# n_iterations: 3
# n_required_iterations: 3
# n_possible_iterations: 4
# min_resources_: 60
# max_resources_: 3000
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 20
# n_resources: 60
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ----------
# iter: 1
# n_candidates: 7
# n_resources: 180
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# ----------
# iter: 2
# n_candidates: 3
# n_resources: 540
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
#       -> [Tuned_Baseline] Acc: 1.0000, F1: 1.0000, Time: 0.01s
#       [+] Saved to Brewed_vinegar_S5_results.csv
#       Generating 2x synthetic data with Jittering...
# ...
