# %% [markdown]
# # Run Experiment Pipeline for Chinese_wine
# To ensure safety and track progress, the experiment is split into 3 cells corresponding to Seed Size: 1, 2, 5.
# The results of each cell will be saved to a separate CSV file.

# %%
# %run ../experiment.py --dataset Chinese_wine --seed 1
# Out:
# ...
# Running experiment for Chinese_wine
# ...
#
# --- Fold 1/10 ---
#
#   >> Seed sets per label: 1
#     Evaluating Model: KNN
#       -> [Baseline] Acc: 0.5703, F1: 0.5418, Time: 0.03s
#       [+] Saved to Chinese_wine_S1_results.csv
#       HP Tuning KNN...
# n_iterations: 3
# n_required_iterations: 3
# n_possible_iterations: 3
# min_resources_: 40
# max_resources_: 1000
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 20
# n_resources: 40
# Fitting 2 folds for each of 20 candidates, totalling 40 fits
# ----------
# iter: 1
# n_candidates: 7
# n_resources: 120
# Fitting 2 folds for each of 7 candidates, totalling 14 fits
# ----------
# iter: 2
# n_candidates: 3
# n_resources: 360
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
#       -> [Tuned_Baseline] Acc: 0.5687, F1: 0.5397, Time: 0.03s
#       [+] Saved to Chinese_wine_S1_results.csv
#       Generating 2x synthetic data with Jittering...
# ...

# %%
# %run ../experiment.py --dataset Chinese_wine --seed 2
# Out:
# ...
# Running experiment for Chinese_wine
# ...
#
# --- Fold 1/10 ---
#
#   >> Seed sets per label: 2
#     Evaluating Model: KNN
#       -> [Baseline] Acc: 0.6550, F1: 0.6423, Time: 0.04s
#       [+] Saved to Chinese_wine_S2_results.csv
#       HP Tuning KNN...
# n_iterations: 3
# n_required_iterations: 3
# n_possible_iterations: 4
# min_resources_: 40
# max_resources_: 2000
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 20
# n_resources: 40
# Fitting 2 folds for each of 20 candidates, totalling 40 fits
# ----------
# iter: 1
# n_candidates: 7
# n_resources: 120
# Fitting 2 folds for each of 7 candidates, totalling 14 fits
# ----------
# iter: 2
# n_candidates: 3
# n_resources: 360
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
#       -> [Tuned_Baseline] Acc: 0.6536, F1: 0.6414, Time: 0.04s
#       [+] Saved to Chinese_wine_S2_results.csv
#       Generating 2x synthetic data with Jittering...
# ...

# %%
# %run ../experiment.py --dataset Chinese_wine --seed 5
# Out:
# ...
# Running experiment for Chinese_wine
# ...
#
# --- Fold 1/10 ---
#
#   >> Seed sets per label: 5
#     Evaluating Model: KNN
#       -> [Baseline] Acc: 0.7591, F1: 0.7540, Time: 0.05s
#       [+] Saved to Chinese_wine_S5_results.csv
#       HP Tuning KNN...
# n_iterations: 3
# n_required_iterations: 3
# n_possible_iterations: 4
# min_resources_: 100
# max_resources_: 5000
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 20
# n_resources: 100
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ----------
# iter: 1
# n_candidates: 7
# n_resources: 300
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# ----------
# iter: 2
# n_candidates: 3
# n_resources: 900
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
#       -> [Tuned_Baseline] Acc: 0.7599, F1: 0.7554, Time: 0.05s
#       [+] Saved to Chinese_wine_S5_results.csv
#       Generating 2x synthetic data with Jittering...
# ...
