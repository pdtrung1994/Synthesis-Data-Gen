# %% [markdown]
# # Run Experiment Pipeline for Chinese_wine
# To ensure safety and track progress, the experiment is split into 2 cells corresponding to Seed Size: 10, 20.
# The results of each cell will be saved to a separate CSV file.

# %%
# %run ../experiment.py --dataset Chinese_wine --seed 10
# Out:
# ...
# Running experiment for Chinese_wine
# ...
#
# --- Fold 1/10 ---
#
#   >> Seed sets per label: 10
#     Evaluating Model: KNN
#       -> [Baseline] Acc: 0.7966, F1: 0.7976, Time: 0.05s
#       [+] Saved to Chinese_wine_S10_results.csv
#       HP Tuning KNN...
# n_iterations: 3
# n_required_iterations: 3
# n_possible_iterations: 5
# min_resources_: 100
# max_resources_: 10000
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 20
# n_resources: 100
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ----------
# iter: 1
# n_candidates: 7
# n_resources: 300
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# ----------
# iter: 2
# n_candidates: 3
# n_resources: 900
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
#       -> [Tuned_Baseline] Acc: 0.7984, F1: 0.7996, Time: 0.05s
#       [+] Saved to Chinese_wine_S10_results.csv
#       Generating 2x synthetic data with Jittering...
# ...

# %%
# %run ../experiment.py --dataset Chinese_wine --seed 20
# Out:
# ...
# Running experiment for Chinese_wine
# ...
#
# --- Fold 1/10 ---
#
#   >> Seed sets per label: 20
#     Evaluating Model: KNN
#       -> [Baseline] Acc: 0.8559, F1: 0.8555, Time: 0.06s
#       [+] Saved to Chinese_wine_S20_results.csv
#       HP Tuning KNN...
# n_iterations: 3
# n_required_iterations: 3
# n_possible_iterations: 5
# min_resources_: 100
# max_resources_: 20000
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 20
# n_resources: 100
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ----------
# iter: 1
# n_candidates: 7
# n_resources: 300
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# ----------
# iter: 2
# n_candidates: 3
# n_resources: 900
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
#       -> [Tuned_Baseline] Acc: 0.8593, F1: 0.8585, Time: 0.03s
#       [+] Saved to Chinese_wine_S20_results.csv
#       Generating 2x synthetic data with Jittering...
# ...
