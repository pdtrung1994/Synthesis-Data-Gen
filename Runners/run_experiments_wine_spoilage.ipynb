# %% [markdown]
# # Run Experiment Pipeline for Wine_spoilage
# To ensure safety and track progress, the experiment is split into 3 cells corresponding to Seed Size: 1, 2, 5.
# The results of each cell will be saved to a separate CSV file.

# %%
# %run ../experiment.py --dataset Wine_spoilage --seed 1
# Out:
# ...
# Running experiment for Wine_spoilage
# ...
#
# --- Fold 1/10 ---
#
#   >> Seed sets per label: 1
#     Evaluating Model: KNN
#       -> [Baseline] Acc: 0.7919, F1: 0.7922, Time: 0.01s
#       [+] Saved to Wine_spoilage_S1_results.csv
#       HP Tuning KNN...
# n_iterations: 3
# n_required_iterations: 3
# n_possible_iterations: 3
# min_resources_: 16
# max_resources_: 400
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 20
# n_resources: 16
# Fitting 2 folds for each of 20 candidates, totalling 40 fits
# ----------
# iter: 1
# n_candidates: 7
# n_resources: 48
# Fitting 2 folds for each of 7 candidates, totalling 14 fits
# ----------
# iter: 2
# n_candidates: 3
# n_resources: 144
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
#       -> [Tuned_Baseline] Acc: 0.7832, F1: 0.7854, Time: 0.01s
#       [+] Saved to Wine_spoilage_S1_results.csv
#       Generating 2x synthetic data with Jittering...
# ...

# %%
# %run ../experiment.py --dataset Wine_spoilage --seed 2
# Out:
# ...
# Running experiment for Wine_spoilage
# ...
#
# --- Fold 1/10 ---
#
#   >> Seed sets per label: 2
#     Evaluating Model: KNN
#       -> [Baseline] Acc: 0.8403, F1: 0.8301, Time: 0.01s
#       [+] Saved to Wine_spoilage_S2_results.csv
#       HP Tuning KNN...
# n_iterations: 3
# n_required_iterations: 3
# n_possible_iterations: 4
# min_resources_: 16
# max_resources_: 800
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 20
# n_resources: 16
# Fitting 2 folds for each of 20 candidates, totalling 40 fits
# ----------
# iter: 1
# n_candidates: 7
# n_resources: 48
# Fitting 2 folds for each of 7 candidates, totalling 14 fits
# ----------
# iter: 2
# n_candidates: 3
# n_resources: 144
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
#       -> [Tuned_Baseline] Acc: 0.8400, F1: 0.8301, Time: 0.01s
#       [+] Saved to Wine_spoilage_S2_results.csv
#       Generating 2x synthetic data with Jittering...
# ...

# %%
# %run ../experiment.py --dataset Wine_spoilage --seed 5
# Out:
# ...
# Running experiment for Wine_spoilage
# ...
#
# --- Fold 1/10 ---
#
#   >> Seed sets per label: 5
#     Evaluating Model: KNN
#       -> [Baseline] Acc: 0.8352, F1: 0.8294, Time: 0.02s
#       [+] Saved to Wine_spoilage_S5_results.csv
#       HP Tuning KNN...
# n_iterations: 3
# n_required_iterations: 3
# n_possible_iterations: 4
# min_resources_: 40
# max_resources_: 2000
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 20
# n_resources: 40
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ----------
# iter: 1
# n_candidates: 7
# n_resources: 120
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# ----------
# iter: 2
# n_candidates: 3
# n_resources: 360
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
#       -> [Tuned_Baseline] Acc: 0.8303, F1: 0.8221, Time: 0.02s
#       [+] Saved to Wine_spoilage_S5_results.csv
#       Generating 2x synthetic data with Jittering...
# ...
